# %% [markdown]
# # Gleam
# Gleam ("lueur") est le nom donné à ce notebook, le produit de ce travail de bachelor. Il permet d'entraîner un réseau de neurones à convolutions sur des images satellites nocturnes dans le but de prédire la répartition de la population sur une vaste région avec une précision supérieure à toutes autres sources de données disponibles.
#
# ## Région d'intérêt
# La région qui nous intéresse le plus dans ce travail est la **Colombie**. Le conflit armé colombien s'est apaisé durant ces 5 dernières années, ce qui a engendré un fort déplacement de la population vers la forêt amazonienne devenue moins dangereuse. Les rencements disponibles ne permettent pas de quantifier ni de localiser avec précision ces mouvements de population. Les images satellites nocturnes récentes, cependant, peuvent révéler ces informations.
#
# ## Fichiers
# Les jeux de données en entrée doivent être des **rasters** au format GeoTIFF possédant deux couches. La première couche est l'image satellite, la seconde doit contenir les données de densité de population (habitants par pixel).

# %% [markdown]
# # Imports

# %%
import rasterio
import numpy as np
import keras.layers.core as core
import keras.layers.convolutional as conv
import keras.models as models
import keras.callbacks
from sklearn.model_selection import KFold
from keras import optimizers
import time

# %% [markdown]
# # Parameters

# %%
input_tile_size = 32
input_tile_offset = 32 # same as input_tile_size for testing purposes, otherwise set to 8
training_dataset = '../../data/lightpop_merged/2015_brazil.tif'
nb_epoch = 200

# %% [markdown]
# # Preprocessing

# %%
print('opening raster')

raster = rasterio.open(training_dataset)

matrix_x = raster.read(1)
matrix_y = raster.read(2)

X = []
Y = []
col = 0
while col + input_tile_size < matrix_x.shape[1]:
    row = 0
    while row + input_tile_size < matrix_x.shape[0]:
        pop = np.sum(matrix_y[row: row + input_tile_size, col: col + input_tile_size])
        # only use tiles that have people living on it
        if pop > 0:
            X.append(matrix_x[row: row + input_tile_size, col: col + input_tile_size])
            Y.append(pop)

        row += input_tile_offset
    col += input_tile_offset

raster.close()

matrix_x, matrix_y = None, None  # free some memory
X, Y = np.array(X), np.array(Y)
X = np.expand_dims(X, axis=3)  # add the color channel as a new dimension

print('input shape (observations, obs_width, obs_height, channels) : ' + str(X.shape))
# Out:
# opening raster
# input shape (observations, obs_width, obs_height, channels) : (39157, 32, 32, 1)

# %% [markdown]
# # Training

# %%
model_birthday = time.strftime("%Y-%m-%d_%H-%M-%S", time.gmtime())  # used to identify generated files (logs and models)

print('configuring cnn')

# kernel size for every convolution layer
kernel_size = (3, 3)

# input dimensions
img_count, img_rows, img_cols, img_channel_count = X.shape

# k-fold split
kfold = KFold(n_splits = 4, shuffle=True, random_state=None)

# initialize statistics aggregate
kfold_mse = []
kfold_mae = []
kfold_sae = []

print('logs will be saved to logs/' + model_birthday)

for train, test in kfold.split(X, Y):
    cnn = models.Sequential()
    cnn.add(conv.Convolution2D(filters=32, kernel_size=kernel_size, activation="relu", padding='same',
                               input_shape=(img_rows, img_cols, img_channel_count)))
    
    cnn.add(conv.MaxPooling2D(strides=(2, 2)))
    
    cnn.add(conv.Convolution2D(filters=64, kernel_size=kernel_size, activation="relu", padding='same'))

    cnn.add(conv.MaxPooling2D(strides=(2, 2)))
    
    cnn.add(conv.Convolution2D(filters=128, kernel_size=kernel_size, activation="relu", padding='same'))

    cnn.add(conv.MaxPooling2D(strides=(2, 2)))
    
    cnn.add(core.Flatten())
    cnn.add(core.Dropout(0.5))
    cnn.add(core.Dense(64))
    cnn.add(core.Dense(1))

    cnn.summary()
    cnn.compile(loss="mean_squared_error", optimizer=optimizers.Adam(lr=0.02, decay=0.0), metrics=["mse", "mae"])

    # logs for tensorboard
    tensorboard = keras.callbacks.TensorBoard(log_dir="logs/" + model_birthday)

    # checkpoints
    # checkpoint = keras.callbacks.ModelCheckpoint('models/' + model_birthday + '.h5', save_weights_only=False)

    # reduce learning rate when we stopped learning anything
    rlrp = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=15, verbose=1, mode='auto',
                                             min_lr=0.00001)

    print('training ...')

    cnn.fit(X[train], Y[train], batch_size=1024, epochs=nb_epoch, verbose=2, callbacks=[tensorboard, rlrp],
            sample_weight=None)

    cnn.save('models/' + model_birthday + '.h5')

    print('model saved to models/' + model_birthday + '.h5')
    
    evaluation = cnn.evaluate(X[test], Y[test], verbose=2, batch_size=1024)
    evaluation = dict(zip(cnn.metrics_names, evaluation))
    kfold_mse.append(evaluation['mean_squared_error'])
    kfold_mae.append(evaluation['mean_absolute_error'])
    kfold_sae.append(evaluation['mean_absolute_error'] * len(Y[test]))

print('done !')
print('K-fold validation results :')
print('Mean squared error : %.2f (std %.2f)' % (np.mean(kfold_mse), np.std(kfold_mse)))
print('Mean absolute error : %.2f (std %.2f)' % (np.mean(kfold_mae), np.std(kfold_mae)))
print('Sum of absolute errors : %.2f (std %.2f)' % (np.mean(kfold_sae), np.std(kfold_sae)))
# Out:
# configuring cnn
# logs will be saved to logs/2018-07-04_19-52-38
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_91 (Conv2D)           (None, 32, 32, 32)        320
# _________________________________________________________________
# max_pooling2d_85 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_92 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_86 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_87 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_42 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_89 (Dense)             (None, 64)                131136
# _________________________________________________________________
# dense_90 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 223,873
# Trainable params: 223,873
# Non-trainable params: 0
# _________________________________________________________________
# training ...
# Epoch 1/200
#  - 2s - loss: 12821788438.0634 - mean_squared_error: 12821788438.0634 - mean_absolute_error: 14479.1207
# Epoch 2/200
#  - 1s - loss: 12321432832.8630 - mean_squared_error: 12321432832.8630 - mean_absolute_error: 14422.3579
# Epoch 3/200
#  - 1s - loss: 6071070784.1068 - mean_squared_error: 6071070784.1068 - mean_absolute_error: 11766.8637
# Epoch 4/200
#  - 1s - loss: 8286427243.7977 - mean_squared_error: 8286427243.7977 - mean_absolute_error: 12383.5982
# Epoch 5/200
#  - 1s - loss: 16775065449.1913 - mean_squared_error: 16775065449.1913 - mean_absolute_error: 23916.0984
# Epoch 6/200
#  - 1s - loss: 13405824491.4272 - mean_squared_error: 13405824491.4272 - mean_absolute_error: 13977.8699
# Epoch 7/200
#  - 1s - loss: 11118788947.2063 - mean_squared_error: 11118788947.2063 - mean_absolute_error: 13543.1609
# Epoch 8/200
#  - 1s - loss: 7764428122.9690 - mean_squared_error: 7764428122.9690 - mean_absolute_error: 12463.0031
# Epoch 9/200
#  - 1s - loss: 7652463978.6732 - mean_squared_error: 7652463978.6732 - mean_absolute_error: 12822.9820
# Epoch 10/200
#  - 1s - loss: 6110121669.6553 - mean_squared_error: 6110121669.6553 - mean_absolute_error: 11820.4164
# Epoch 11/200
#  - 1s - loss: 9865534769.5555 - mean_squared_error: 9865534769.5555 - mean_absolute_error: 14248.2777
# Epoch 12/200
#  - 1s - loss: 6237143625.5214 - mean_squared_error: 6237143625.5214 - mean_absolute_error: 10835.3681
# Epoch 13/200
#  - 1s - loss: 9950413903.9286 - mean_squared_error: 9950413903.9286 - mean_absolute_error: 12999.9745
# Epoch 14/200
#  - 1s - loss: 4916735521.2128 - mean_squared_error: 4916735521.2128 - mean_absolute_error: 11429.3415
# Epoch 15/200
#  - 1s - loss: 3755876693.9479 - mean_squared_error: 3755876693.9479 - mean_absolute_error: 11013.1738
# Epoch 16/200
#  - 1s - loss: 4548411697.8018 - mean_squared_error: 4548411697.8018 - mean_absolute_error: 10548.8240
# Epoch 17/200
#  - 1s - loss: 3955650763.2692 - mean_squared_error: 3955650763.2692 - mean_absolute_error: 10748.3858
# Epoch 18/200
#  - 1s - loss: 2431140460.8787 - mean_squared_error: 2431140460.8787 - mean_absolute_error: 9416.9587
# Epoch 19/200
#  - 1s - loss: 3882859023.0111 - mean_squared_error: 3882859023.0111 - mean_absolute_error: 10034.6515
# Epoch 20/200
#  - 1s - loss: 3526030431.9946 - mean_squared_error: 3526030431.9946 - mean_absolute_error: 9328.5180
# Epoch 21/200
#  - 1s - loss: 3223939201.0286 - mean_squared_error: 3223939201.0286 - mean_absolute_error: 9654.6864
# Epoch 22/200
#  - 1s - loss: 3626558676.8582 - mean_squared_error: 3626558676.8582 - mean_absolute_error: 9642.3919
# Epoch 23/200
#  - 1s - loss: 3430849475.0227 - mean_squared_error: 3430849475.0227 - mean_absolute_error: 9524.8096
# Epoch 24/200
#  - 1s - loss: 2858970828.2390 - mean_squared_error: 2858970828.2390 - mean_absolute_error: 9358.3857
# Epoch 25/200
#  - 1s - loss: 4152113409.0025 - mean_squared_error: 4152113409.0025 - mean_absolute_error: 9558.0128
# Epoch 26/200
#  - 1s - loss: 3707815905.2956 - mean_squared_error: 3707815905.2956 - mean_absolute_error: 9569.1903
# Epoch 27/200
#  - 1s - loss: 3562031144.2215 - mean_squared_error: 3562031144.2215 - mean_absolute_error: 9677.4155
# Epoch 28/200
#  - 1s - loss: 2821861848.2231 - mean_squared_error: 2821861848.2231 - mean_absolute_error: 9424.0826
# Epoch 29/200
#  - 1s - loss: 2537271467.8958 - mean_squared_error: 2537271467.8958 - mean_absolute_error: 9093.3554
# Epoch 30/200
#  - 1s - loss: 2564487756.6291 - mean_squared_error: 2564487756.6291 - mean_absolute_error: 9351.7881
# Epoch 31/200
#  - 1s - loss: 2244656965.4592 - mean_squared_error: 2244656965.4592 - mean_absolute_error: 9024.4002
# Epoch 32/200
#  - 1s - loss: 2013297598.9147 - mean_squared_error: 2013297598.9147 - mean_absolute_error: 8738.0245
# Epoch 33/200
#  - 1s - loss: 3029297809.1817 - mean_squared_error: 3029297809.1817 - mean_absolute_error: 9096.0650
# Epoch 34/200
#  - 1s - loss: 1976957651.3371 - mean_squared_error: 1976957651.3371 - mean_absolute_error: 8645.3363
# Epoch 35/200
#  - 1s - loss: 5217841523.3338 - mean_squared_error: 5217841523.3338 - mean_absolute_error: 10297.4121
# Epoch 36/200
#  - 1s - loss: 3442809139.7893 - mean_squared_error: 3442809139.7893 - mean_absolute_error: 9430.0613
# Epoch 37/200
#  - 1s - loss: 5870594719.4737 - mean_squared_error: 5870594719.4737 - mean_absolute_error: 10998.1192
# Epoch 38/200
#  - 1s - loss: 5864402934.2018 - mean_squared_error: 5864402934.2018 - mean_absolute_error: 12348.8826
# Epoch 39/200
#  - 1s - loss: 2291582826.4400 - mean_squared_error: 2291582826.4400 - mean_absolute_error: 9399.5109
# Epoch 40/200
#  - 1s - loss: 2526474067.6422 - mean_squared_error: 2526474067.6422 - mean_absolute_error: 9624.0695
# Epoch 41/200
#  - 1s - loss: 2099649115.8626 - mean_squared_error: 2099649115.8626 - mean_absolute_error: 9725.3357
# Epoch 42/200
#  - 1s - loss: 1840583322.7969 - mean_squared_error: 1840583322.7969 - mean_absolute_error: 9351.4637
# Epoch 43/200
#  - 1s - loss: 2940175656.0406 - mean_squared_error: 2940175656.0406 - mean_absolute_error: 9671.9500
# Epoch 44/200
#  - 1s - loss: 2035712829.8490 - mean_squared_error: 2035712829.8490 - mean_absolute_error: 9563.2656
# Epoch 45/200
#  - 1s - loss: 2138422951.2560 - mean_squared_error: 2138422951.2560 - mean_absolute_error: 9311.2387
# Epoch 46/200
#  - 1s - loss: 3390917326.2680 - mean_squared_error: 3390917326.2680 - mean_absolute_error: 9868.3584
# Epoch 47/200
#  - 1s - loss: 2449110969.1548 - mean_squared_error: 2449110969.1548 - mean_absolute_error: 9129.2424
# Epoch 48/200
#  - 1s - loss: 2984658877.6049 - mean_squared_error: 2984658877.6049 - mean_absolute_error: 9609.5338
# Epoch 49/200
#  - 1s - loss: 1629459596.0298 - mean_squared_error: 1629459596.0298 - mean_absolute_error: 8584.7782
# Epoch 50/200
#  - 1s - loss: 1502834870.7967 - mean_squared_error: 1502834870.7967 - mean_absolute_error: 8381.3677
# Epoch 51/200
#  - 1s - loss: 2386313363.6182 - mean_squared_error: 2386313363.6182 - mean_absolute_error: 8980.6282
# Epoch 52/200
#  - 1s - loss: 1831821538.5487 - mean_squared_error: 1831821538.5487 - mean_absolute_error: 8757.8805
# Epoch 53/200
#  - 1s - loss: 2455582610.3629 - mean_squared_error: 2455582610.3629 - mean_absolute_error: 9009.3078
# Epoch 54/200
#  - 1s - loss: 1942160013.6294 - mean_squared_error: 1942160013.6294 - mean_absolute_error: 9006.1255
# Epoch 55/200
#  - 1s - loss: 1778082220.9244 - mean_squared_error: 1778082220.9244 - mean_absolute_error: 8379.2336
# Epoch 56/200
#  - 1s - loss: 2234330701.0868 - mean_squared_error: 2234330701.0868 - mean_absolute_error: 8835.3121
# Epoch 57/200
#  - 1s - loss: 1536452985.4947 - mean_squared_error: 1536452985.4947 - mean_absolute_error: 8416.7825
# Epoch 58/200
#  - 1s - loss: 1166713195.1167 - mean_squared_error: 1166713195.1167 - mean_absolute_error: 8072.8101
# Epoch 59/200
#  - 1s - loss: 1495981043.7697 - mean_squared_error: 1495981043.7697 - mean_absolute_error: 8317.2677
# Epoch 60/200
#  - 1s - loss: 2401860914.5122 - mean_squared_error: 2401860914.5122 - mean_absolute_error: 8645.1609
# Epoch 61/200
#  - 1s - loss: 2199968410.1518 - mean_squared_error: 2199968410.1518 - mean_absolute_error: 8568.7772
# Epoch 62/200
#  - 1s - loss: 2470144680.2825 - mean_squared_error: 2470144680.2825 - mean_absolute_error: 9047.3187
# Epoch 63/200
#  - 1s - loss: 1832191261.1920 - mean_squared_error: 1832191261.1920 - mean_absolute_error: 8569.0856
# Epoch 64/200
#  - 1s - loss: 1943642430.8079 - mean_squared_error: 1943642430.8079 - mean_absolute_error: 8375.1442
# Epoch 65/200
#  - 1s - loss: 3198273348.7400 - mean_squared_error: 3198273348.7400 - mean_absolute_error: 9006.8213
# Epoch 66/200
#  - 1s - loss: 3895954891.0949 - mean_squared_error: 3895954891.0949 - mean_absolute_error: 10076.5223
# Epoch 67/200
#  - 1s - loss: 2519328025.9557 - mean_squared_error: 2519328025.9557 - mean_absolute_error: 9614.0479
# Epoch 68/200
#  - 1s - loss: 3644021687.0495 - mean_squared_error: 3644021687.0495 - mean_absolute_error: 9608.7553
# Epoch 69/200
#  - 1s - loss: 2496701753.0153 - mean_squared_error: 2496701753.0153 - mean_absolute_error: 9244.2055
# Epoch 70/200
#  - 1s - loss: 1783441229.6425 - mean_squared_error: 1783441229.6425 - mean_absolute_error: 8372.9526
# Epoch 71/200
#  - 1s - loss: 1365051355.0497 - mean_squared_error: 1365051355.0497 - mean_absolute_error: 8338.8977
# Epoch 72/200
#  - 1s - loss: 1594112133.3241 - mean_squared_error: 1594112133.3241 - mean_absolute_error: 8235.8552
# Epoch 73/200
#  - 1s - loss: 3687241943.4909 - mean_squared_error: 3687241943.4909 - mean_absolute_error: 9160.3116
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 0.009999999776482582.
# Epoch 74/200
#  - 1s - loss: 1802977124.0394 - mean_squared_error: 1802977124.0394 - mean_absolute_error: 8281.3563
# Epoch 75/200
#  - 1s - loss: 1388930637.8365 - mean_squared_error: 1388930637.8365 - mean_absolute_error: 8126.8457
# Epoch 76/200
#  - 1s - loss: 1762797253.4112 - mean_squared_error: 1762797253.4112 - mean_absolute_error: 8530.2400
# Epoch 77/200
#  - 1s - loss: 1537539877.5202 - mean_squared_error: 1537539877.5202 - mean_absolute_error: 8186.9899
# Epoch 78/200
#  - 1s - loss: 1308778442.1807 - mean_squared_error: 1308778442.1807 - mean_absolute_error: 7939.4245
# Epoch 79/200
#  - 1s - loss: 1335355091.5528 - mean_squared_error: 1335355091.5528 - mean_absolute_error: 7795.1447
# Epoch 80/200
#  - 1s - loss: 1388212669.3173 - mean_squared_error: 1388212669.3173 - mean_absolute_error: 7943.3594
# Epoch 81/200
#  - 1s - loss: 1355683830.3674 - mean_squared_error: 1355683830.3674 - mean_absolute_error: 7911.5459
# Epoch 82/200
#  - 1s - loss: 1353123434.8890 - mean_squared_error: 1353123434.8890 - mean_absolute_error: 8062.8772
# Epoch 83/200
#  - 1s - loss: 1238588660.5564 - mean_squared_error: 1238588660.5564 - mean_absolute_error: 7852.2958
# Epoch 84/200
#  - 1s - loss: 1052290908.0554 - mean_squared_error: 1052290908.0554 - mean_absolute_error: 7580.7166
# Epoch 85/200
#  - 1s - loss: 1506898982.3168 - mean_squared_error: 1506898982.3168 - mean_absolute_error: 7728.5661
# Epoch 86/200
#  - 1s - loss: 1275740105.1989 - mean_squared_error: 1275740105.1989 - mean_absolute_error: 7710.3697
# Epoch 87/200
#  - 1s - loss: 1208171338.9336 - mean_squared_error: 1208171338.9336 - mean_absolute_error: 7774.9050
# Epoch 88/200
#  - 1s - loss: 1560099505.4149 - mean_squared_error: 1560099505.4149 - mean_absolute_error: 7893.5729
# Epoch 89/200
#  - 1s - loss: 1813919312.8919 - mean_squared_error: 1813919312.8919 - mean_absolute_error: 7945.1852
# Epoch 90/200
#  - 1s - loss: 951725742.0620 - mean_squared_error: 951725742.0620 - mean_absolute_error: 7349.5006
# Epoch 91/200
#  - 1s - loss: 1969103122.4109 - mean_squared_error: 1969103122.4109 - mean_absolute_error: 7999.9113
# Epoch 92/200
#  - 1s - loss: 1513444984.5533 - mean_squared_error: 1513444984.5533 - mean_absolute_error: 7849.3115
# Epoch 93/200
#  - 1s - loss: 1068434916.0372 - mean_squared_error: 1068434916.0372 - mean_absolute_error: 7638.9760
# Epoch 94/200
#  - 1s - loss: 981014229.4249 - mean_squared_error: 981014229.4249 - mean_absolute_error: 7414.2900
# Epoch 95/200
#  - 1s - loss: 1030099667.8340 - mean_squared_error: 1030099667.8340 - mean_absolute_error: 7383.3322
# Epoch 96/200
#  - 1s - loss: 1045149056.4555 - mean_squared_error: 1045149056.4555 - mean_absolute_error: 7405.6837
# Epoch 97/200
#  - 1s - loss: 894806894.7158 - mean_squared_error: 894806894.7158 - mean_absolute_error: 7356.1023
# Epoch 98/200
#  - 1s - loss: 1145869518.4402 - mean_squared_error: 1145869518.4402 - mean_absolute_error: 7696.2534
# Epoch 99/200
#  - 1s - loss: 1497393145.7672 - mean_squared_error: 1497393145.7672 - mean_absolute_error: 7560.9355
# Epoch 100/200
#  - 1s - loss: 1154589062.1479 - mean_squared_error: 1154589062.1479 - mean_absolute_error: 7374.4409
# Epoch 101/200
#  - 1s - loss: 1622421399.3557 - mean_squared_error: 1622421399.3557 - mean_absolute_error: 8049.9786
# Epoch 102/200
#  - 1s - loss: 1164273123.5643 - mean_squared_error: 1164273123.5643 - mean_absolute_error: 7395.5381
# Epoch 103/200
#  - 1s - loss: 1701302719.0564 - mean_squared_error: 1701302719.0564 - mean_absolute_error: 8022.6601
# Epoch 104/200
#  - 1s - loss: 1070885403.8691 - mean_squared_error: 1070885403.8691 - mean_absolute_error: 7484.5633
# Epoch 105/200
#  - 1s - loss: 1042197247.1686 - mean_squared_error: 1042197247.1686 - mean_absolute_error: 7266.1165
# Epoch 106/200
#  - 1s - loss: 946920552.0395 - mean_squared_error: 946920552.0395 - mean_absolute_error: 7408.8342
# Epoch 107/200
#  - 1s - loss: 1017011991.8090 - mean_squared_error: 1017011991.8090 - mean_absolute_error: 7234.4659
# Epoch 108/200
#  - 1s - loss: 918399067.2938 - mean_squared_error: 918399067.2938 - mean_absolute_error: 7282.3573
# Epoch 109/200
#  - 1s - loss: 969863183.5974 - mean_squared_error: 969863183.5974 - mean_absolute_error: 7390.0342
# Epoch 110/200
#  - 1s - loss: 981732245.3922 - mean_squared_error: 981732245.3922 - mean_absolute_error: 7282.7168
# Epoch 111/200
#  - 1s - loss: 859831523.4204 - mean_squared_error: 859831523.4204 - mean_absolute_error: 7168.8209
# Epoch 112/200
#  - 1s - loss: 1107048068.8664 - mean_squared_error: 1107048068.8664 - mean_absolute_error: 7299.5372
# Epoch 113/200
#  - 1s - loss: 893840287.6480 - mean_squared_error: 893840287.6480 - mean_absolute_error: 7135.7618
# Epoch 114/200
#  - 1s - loss: 1386192153.1984 - mean_squared_error: 1386192153.1984 - mean_absolute_error: 7382.9039
# Epoch 115/200
#  - 1s - loss: 1412109969.5282 - mean_squared_error: 1412109969.5282 - mean_absolute_error: 7242.5636
# Epoch 116/200
#  - 1s - loss: 1144277961.1401 - mean_squared_error: 1144277961.1401 - mean_absolute_error: 7213.4856
# Epoch 117/200
#  - 1s - loss: 1232456092.7708 - mean_squared_error: 1232456092.7708 - mean_absolute_error: 7261.7492
# Epoch 118/200
#  - 1s - loss: 1009248152.4999 - mean_squared_error: 1009248152.4999 - mean_absolute_error: 7258.0830
# Epoch 119/200
#  - 1s - loss: 1637661265.6285 - mean_squared_error: 1637661265.6285 - mean_absolute_error: 7634.2176
# Epoch 120/200
#  - 1s - loss: 1703773652.1816 - mean_squared_error: 1703773652.1816 - mean_absolute_error: 7968.1566
# Epoch 121/200
#  - 1s - loss: 1780177089.4362 - mean_squared_error: 1780177089.4362 - mean_absolute_error: 7785.6870
# Epoch 122/200
#  - 1s - loss: 1159821161.3830 - mean_squared_error: 1159821161.3830 - mean_absolute_error: 7360.2380
# Epoch 123/200
#  - 1s - loss: 1244966092.1366 - mean_squared_error: 1244966092.1366 - mean_absolute_error: 7459.9228
# Epoch 124/200
#  - 1s - loss: 1121073180.5665 - mean_squared_error: 1121073180.5665 - mean_absolute_error: 7263.2859
# Epoch 125/200
#  - 1s - loss: 1012116256.6298 - mean_squared_error: 1012116256.6298 - mean_absolute_error: 7320.0314
# Epoch 126/200
#  - 1s - loss: 1017120606.0637 - mean_squared_error: 1017120606.0637 - mean_absolute_error: 7521.1698
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 127/200
#  - 1s - loss: 955658178.2316 - mean_squared_error: 955658178.2316 - mean_absolute_error: 7232.5133
# Epoch 128/200
#  - 1s - loss: 811447586.8429 - mean_squared_error: 811447586.8429 - mean_absolute_error: 7039.5300
# Epoch 129/200
#  - 1s - loss: 941793873.0575 - mean_squared_error: 941793873.0575 - mean_absolute_error: 7101.1491
# Epoch 130/200
#  - 1s - loss: 728956438.9744 - mean_squared_error: 728956438.9744 - mean_absolute_error: 6853.6922
# Epoch 131/200
#  - 1s - loss: 783179013.9800 - mean_squared_error: 783179013.9800 - mean_absolute_error: 6979.3213
# Epoch 132/200
#  - 1s - loss: 723648977.2972 - mean_squared_error: 723648977.2972 - mean_absolute_error: 6747.9808
# Epoch 133/200
#  - 1s - loss: 846870211.2210 - mean_squared_error: 846870211.2210 - mean_absolute_error: 6886.0574
# Epoch 134/200
#  - 1s - loss: 806211475.0930 - mean_squared_error: 806211475.0930 - mean_absolute_error: 6990.5834
# Epoch 135/200
#  - 1s - loss: 952563873.8056 - mean_squared_error: 952563873.8056 - mean_absolute_error: 7041.0539
# Epoch 136/200
#  - 1s - loss: 826774020.5657 - mean_squared_error: 826774020.5657 - mean_absolute_error: 6964.6706
# Epoch 137/200
#  - 1s - loss: 1045515602.9949 - mean_squared_error: 1045515602.9949 - mean_absolute_error: 7129.5164
# Epoch 138/200
#  - 1s - loss: 822586371.8503 - mean_squared_error: 822586371.8503 - mean_absolute_error: 6784.3562
# Epoch 139/200
#  - 1s - loss: 755921285.7076 - mean_squared_error: 755921285.7076 - mean_absolute_error: 6808.2613
# Epoch 140/200
#  - 1s - loss: 847101048.7407 - mean_squared_error: 847101048.7407 - mean_absolute_error: 6875.5285
# Epoch 141/200
#  - 1s - loss: 815597318.7276 - mean_squared_error: 815597318.7276 - mean_absolute_error: 6979.1556
# Epoch 142/200
#  - 1s - loss: 793284723.4123 - mean_squared_error: 793284723.4123 - mean_absolute_error: 6850.0610
# Epoch 143/200
#  - 1s - loss: 751732134.3429 - mean_squared_error: 751732134.3429 - mean_absolute_error: 6751.7956
# Epoch 144/200
#  - 1s - loss: 949169943.3732 - mean_squared_error: 949169943.3732 - mean_absolute_error: 6815.9559
# Epoch 145/200
#  - 1s - loss: 772657020.2222 - mean_squared_error: 772657020.2222 - mean_absolute_error: 6842.1008
# Epoch 146/200
#  - 1s - loss: 751956576.2212 - mean_squared_error: 751956576.2212 - mean_absolute_error: 6927.0172
# Epoch 147/200
#  - 1s - loss: 798175050.1665 - mean_squared_error: 798175050.1665 - mean_absolute_error: 6845.5660
#
# Epoch 00147: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 148/200
#  - 1s - loss: 788688569.2681 - mean_squared_error: 788688569.2681 - mean_absolute_error: 6822.8451
# Epoch 149/200
#  - 1s - loss: 835359718.1489 - mean_squared_error: 835359718.1489 - mean_absolute_error: 6762.8447
# Epoch 150/200
#  - 1s - loss: 896755916.9626 - mean_squared_error: 896755916.9626 - mean_absolute_error: 6902.7389
# Epoch 151/200
#  - 1s - loss: 766630580.0617 - mean_squared_error: 766630580.0617 - mean_absolute_error: 6707.9033
# Epoch 152/200
#  - 1s - loss: 669271806.0964 - mean_squared_error: 669271806.0964 - mean_absolute_error: 6545.3852
# Epoch 153/200
#  - 1s - loss: 694344190.2391 - mean_squared_error: 694344190.2391 - mean_absolute_error: 6660.9506
# Epoch 154/200
#  - 1s - loss: 685360582.5619 - mean_squared_error: 685360582.5619 - mean_absolute_error: 6633.5925
# Epoch 155/200
#  - 1s - loss: 793692417.7696 - mean_squared_error: 793692417.7696 - mean_absolute_error: 6668.1076
# Epoch 156/200
#  - 1s - loss: 804953639.7638 - mean_squared_error: 804953639.7638 - mean_absolute_error: 6794.8863
# Epoch 157/200
#  - 1s - loss: 998930480.0147 - mean_squared_error: 998930480.0147 - mean_absolute_error: 6810.3350
# Epoch 158/200
#  - 1s - loss: 756354549.4957 - mean_squared_error: 756354549.4957 - mean_absolute_error: 6813.4229
# Epoch 159/200
#  - 1s - loss: 770165248.0087 - mean_squared_error: 770165248.0087 - mean_absolute_error: 6688.2005
# Epoch 160/200
#  - 1s - loss: 798919904.7519 - mean_squared_error: 798919904.7519 - mean_absolute_error: 6789.6028
# Epoch 161/200
#  - 1s - loss: 702129745.6416 - mean_squared_error: 702129745.6416 - mean_absolute_error: 6541.1316
# Epoch 162/200
#  - 1s - loss: 722530508.4308 - mean_squared_error: 722530508.4308 - mean_absolute_error: 6673.7215
# Epoch 163/200
#  - 1s - loss: 784047047.4751 - mean_squared_error: 784047047.4751 - mean_absolute_error: 6679.8270
# Epoch 164/200
#  - 1s - loss: 742502434.0017 - mean_squared_error: 742502434.0017 - mean_absolute_error: 6696.3011
# Epoch 165/200
#  - 1s - loss: 725998865.6546 - mean_squared_error: 725998865.6546 - mean_absolute_error: 6589.5728
# Epoch 166/200
#  - 1s - loss: 793445018.7773 - mean_squared_error: 793445018.7773 - mean_absolute_error: 6737.4595
# Epoch 167/200
#  - 1s - loss: 686293955.8792 - mean_squared_error: 686293955.8792 - mean_absolute_error: 6591.6112
#
# Epoch 00167: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 168/200
#  - 1s - loss: 592274685.8032 - mean_squared_error: 592274685.8032 - mean_absolute_error: 6472.7977
# Epoch 169/200
#  - 1s - loss: 651772397.5281 - mean_squared_error: 651772397.5281 - mean_absolute_error: 6621.7066
# Epoch 170/200
#  - 1s - loss: 702179821.6186 - mean_squared_error: 702179821.6186 - mean_absolute_error: 6591.8050
# Epoch 171/200
#  - 1s - loss: 754288410.9233 - mean_squared_error: 754288410.9233 - mean_absolute_error: 6540.2910
# Epoch 172/200
#  - 1s - loss: 776695362.4256 - mean_squared_error: 776695362.4256 - mean_absolute_error: 6765.7954
# Epoch 173/200
#  - 1s - loss: 689691424.5884 - mean_squared_error: 689691424.5884 - mean_absolute_error: 6479.1440
# Epoch 174/200
#  - 1s - loss: 762047147.6430 - mean_squared_error: 762047147.6430 - mean_absolute_error: 6671.9485
# Epoch 175/200
#  - 1s - loss: 778741089.6857 - mean_squared_error: 778741089.6857 - mean_absolute_error: 6740.2146
# Epoch 176/200
#  - 1s - loss: 632872386.5890 - mean_squared_error: 632872386.5890 - mean_absolute_error: 6471.3937
# Epoch 177/200
#  - 1s - loss: 822260471.5225 - mean_squared_error: 822260471.5225 - mean_absolute_error: 6629.9499
# Epoch 178/200
#  - 1s - loss: 713613596.9326 - mean_squared_error: 713613596.9326 - mean_absolute_error: 6503.2638
# Epoch 179/200
#  - 1s - loss: 603102430.8548 - mean_squared_error: 603102430.8548 - mean_absolute_error: 6482.2189
# Epoch 180/200
#  - 1s - loss: 839389099.0317 - mean_squared_error: 839389099.0317 - mean_absolute_error: 6564.8977
# Epoch 181/200
#  - 1s - loss: 723101911.2381 - mean_squared_error: 723101911.2381 - mean_absolute_error: 6667.5989
# Epoch 182/200
#  - 1s - loss: 710481027.2101 - mean_squared_error: 710481027.2101 - mean_absolute_error: 6615.9671
# Epoch 183/200
#  - 1s - loss: 631484626.1733 - mean_squared_error: 631484626.1733 - mean_absolute_error: 6465.1075
#
# Epoch 00183: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 184/200
#  - 1s - loss: 698329153.4155 - mean_squared_error: 698329153.4155 - mean_absolute_error: 6642.0356
# Epoch 185/200
#  - 1s - loss: 580157885.8343 - mean_squared_error: 580157885.8343 - mean_absolute_error: 6446.4520
# Epoch 186/200
#  - 1s - loss: 575699699.5768 - mean_squared_error: 575699699.5768 - mean_absolute_error: 6447.7953
# Epoch 187/200
#  - 1s - loss: 681160996.8283 - mean_squared_error: 681160996.8283 - mean_absolute_error: 6597.6539
# Epoch 188/200
#  - 1s - loss: 693264281.0229 - mean_squared_error: 693264281.0229 - mean_absolute_error: 6640.8472
# Epoch 189/200
#  - 1s - loss: 661775191.9485 - mean_squared_error: 661775191.9485 - mean_absolute_error: 6485.3406
# Epoch 190/200
#  - 1s - loss: 565189849.1046 - mean_squared_error: 565189849.1046 - mean_absolute_error: 6405.4895
# Epoch 191/200
#  - 1s - loss: 735659330.5117 - mean_squared_error: 735659330.5117 - mean_absolute_error: 6613.6645
# Epoch 192/200
#  - 1s - loss: 703360716.1758 - mean_squared_error: 703360716.1758 - mean_absolute_error: 6491.4696
# Epoch 193/200
#  - 1s - loss: 663444522.5130 - mean_squared_error: 663444522.5130 - mean_absolute_error: 6588.8189
# Epoch 194/200
#  - 1s - loss: 725539750.0067 - mean_squared_error: 725539750.0067 - mean_absolute_error: 6581.2178
# Epoch 195/200
#  - 1s - loss: 664095641.4326 - mean_squared_error: 664095641.4326 - mean_absolute_error: 6532.1703
# Epoch 196/200
#  - 1s - loss: 737430006.2955 - mean_squared_error: 737430006.2955 - mean_absolute_error: 6552.5159
# Epoch 197/200
#  - 1s - loss: 587748374.9460 - mean_squared_error: 587748374.9460 - mean_absolute_error: 6463.4035
# Epoch 198/200
#  - 1s - loss: 584893857.3359 - mean_squared_error: 584893857.3359 - mean_absolute_error: 6370.0065
# Epoch 199/200
#  - 1s - loss: 669217516.7261 - mean_squared_error: 669217516.7261 - mean_absolute_error: 6549.0157
# Epoch 200/200
#  - 1s - loss: 560818546.1788 - mean_squared_error: 560818546.1788 - mean_absolute_error: 6360.0828
# model saved to models/2018-07-04_19-52-38.h5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_94 (Conv2D)           (None, 32, 32, 32)        320
# _________________________________________________________________
# max_pooling2d_88 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_89 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_90 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_91 (Dense)             (None, 64)                131136
# _________________________________________________________________
# dense_92 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 223,873
# Trainable params: 223,873
# Non-trainable params: 0
# _________________________________________________________________
# training ...
# Epoch 1/200
#  - 2s - loss: 22159384875.5849 - mean_squared_error: 22159384875.5849 - mean_absolute_error: 18224.8055
# Epoch 2/200
#  - 1s - loss: 10918163111.3658 - mean_squared_error: 10918163111.3658 - mean_absolute_error: 13720.1341
# Epoch 3/200
#  - 1s - loss: 11402454376.2550 - mean_squared_error: 11402454376.2550 - mean_absolute_error: 13948.3375
# Epoch 4/200
#  - 1s - loss: 6456705417.4492 - mean_squared_error: 6456705417.4492 - mean_absolute_error: 12210.0694
# Epoch 5/200
#  - 1s - loss: 8158131789.4067 - mean_squared_error: 8158131789.4067 - mean_absolute_error: 12573.9936
# Epoch 6/200
#  - 1s - loss: 10916091130.9790 - mean_squared_error: 10916091130.9790 - mean_absolute_error: 14191.7916
# Epoch 7/200
#  - 1s - loss: 8484272646.8341 - mean_squared_error: 8484272646.8341 - mean_absolute_error: 13282.6633
# Epoch 8/200
#  - 1s - loss: 11086904281.7848 - mean_squared_error: 11086904281.7848 - mean_absolute_error: 15084.0167
# Epoch 9/200
#  - 1s - loss: 4725325078.5247 - mean_squared_error: 4725325078.5247 - mean_absolute_error: 13172.2094
# Epoch 10/200
#  - 1s - loss: 4959645940.9120 - mean_squared_error: 4959645940.9120 - mean_absolute_error: 13992.7709
# Epoch 11/200
#  - 1s - loss: 4602669003.5587 - mean_squared_error: 4602669003.5587 - mean_absolute_error: 11478.5720
# Epoch 12/200
#  - 1s - loss: 7904318109.9166 - mean_squared_error: 7904318109.9166 - mean_absolute_error: 10963.9627
# Epoch 13/200
#  - 1s - loss: 10348409261.3980 - mean_squared_error: 10348409261.3980 - mean_absolute_error: 12656.7341
# Epoch 14/200
#  - 1s - loss: 5545767475.6045 - mean_squared_error: 5545767475.6045 - mean_absolute_error: 10551.5684
# Epoch 15/200
#  - 1s - loss: 9784351756.0294 - mean_squared_error: 9784351756.0294 - mean_absolute_error: 11543.0189
# Epoch 16/200
#  - 1s - loss: 14150603960.3814 - mean_squared_error: 14150603960.3814 - mean_absolute_error: 13675.8688
# Epoch 17/200
#  - 1s - loss: 10205475659.0706 - mean_squared_error: 10205475659.0706 - mean_absolute_error: 12098.5569
# Epoch 18/200
#  - 1s - loss: 4836404512.4271 - mean_squared_error: 4836404512.4271 - mean_absolute_error: 9898.0684
# Epoch 19/200
#  - 1s - loss: 5586282804.5808 - mean_squared_error: 5586282804.5808 - mean_absolute_error: 10410.2958
# Epoch 20/200
#  - 1s - loss: 4069636492.9360 - mean_squared_error: 4069636492.9360 - mean_absolute_error: 9373.2118
# Epoch 21/200
#  - 1s - loss: 6798920728.5470 - mean_squared_error: 6798920728.5470 - mean_absolute_error: 10229.8430
# Epoch 22/200
#  - 1s - loss: 4890408075.1926 - mean_squared_error: 4890408075.1926 - mean_absolute_error: 11253.0105
# Epoch 23/200
#  - 1s - loss: 4966955980.3955 - mean_squared_error: 4966955980.3955 - mean_absolute_error: 11187.2176
# Epoch 24/200
#  - 1s - loss: 4153478990.3133 - mean_squared_error: 4153478990.3133 - mean_absolute_error: 9875.9057
# Epoch 25/200
#  - 1s - loss: 19151857910.0278 - mean_squared_error: 19151857910.0278 - mean_absolute_error: 17000.9455
# Epoch 26/200
#  - 1s - loss: 5572201706.1030 - mean_squared_error: 5572201706.1030 - mean_absolute_error: 13155.7670
# Epoch 27/200
#  - 1s - loss: 5588940244.8597 - mean_squared_error: 5588940244.8597 - mean_absolute_error: 12310.1419
# Epoch 28/200
#  - 1s - loss: 7562469391.6208 - mean_squared_error: 7562469391.6208 - mean_absolute_error: 12078.5740
# Epoch 29/200
#  - 1s - loss: 6385260112.9632 - mean_squared_error: 6385260112.9632 - mean_absolute_error: 11809.4573
# Epoch 30/200
#  - 1s - loss: 5413507218.7241 - mean_squared_error: 5413507218.7241 - mean_absolute_error: 11434.6740
# Epoch 31/200
#  - 1s - loss: 6006290350.5138 - mean_squared_error: 6006290350.5138 - mean_absolute_error: 12092.4361
# Epoch 32/200
#  - 1s - loss: 4197672678.9649 - mean_squared_error: 4197672678.9649 - mean_absolute_error: 10796.6503
# Epoch 33/200
#  - 1s - loss: 4625237148.4871 - mean_squared_error: 4625237148.4871 - mean_absolute_error: 11123.3983
# Epoch 34/200
#  - 1s - loss: 3773233598.7273 - mean_squared_error: 3773233598.7273 - mean_absolute_error: 10825.5728
# Epoch 35/200
#  - 1s - loss: 3882232574.2566 - mean_squared_error: 3882232574.2566 - mean_absolute_error: 10860.8822
# Epoch 36/200
#  - 1s - loss: 4263267891.7091 - mean_squared_error: 4263267891.7091 - mean_absolute_error: 10635.3394
# Epoch 37/200
#  - 1s - loss: 3672645949.8556 - mean_squared_error: 3672645949.8556 - mean_absolute_error: 10164.4611
# Epoch 38/200
#  - 1s - loss: 3209735023.6470 - mean_squared_error: 3209735023.6470 - mean_absolute_error: 9893.5360
# Epoch 39/200
#  - 1s - loss: 3001473003.6372 - mean_squared_error: 3001473003.6372 - mean_absolute_error: 9862.6359
# Epoch 40/200
#  - 1s - loss: 4090443631.0193 - mean_squared_error: 4090443631.0193 - mean_absolute_error: 10043.3188
# Epoch 41/200
#  - 1s - loss: 3541287014.6510 - mean_squared_error: 3541287014.6510 - mean_absolute_error: 10041.1022
# Epoch 42/200
#  - 1s - loss: 3612573856.3225 - mean_squared_error: 3612573856.3225 - mean_absolute_error: 10351.4225
# Epoch 43/200
#  - 1s - loss: 2584115913.3620 - mean_squared_error: 2584115913.3620 - mean_absolute_error: 9898.4695
# Epoch 44/200
#  - 1s - loss: 2725190599.5663 - mean_squared_error: 2725190599.5663 - mean_absolute_error: 9769.8275
# Epoch 45/200
#  - 1s - loss: 3276829444.5851 - mean_squared_error: 3276829444.5851 - mean_absolute_error: 10203.2829
# Epoch 46/200
#  - 1s - loss: 2443197878.3242 - mean_squared_error: 2443197878.3242 - mean_absolute_error: 9373.6340
# Epoch 47/200
#  - 1s - loss: 2939718973.1234 - mean_squared_error: 2939718973.1234 - mean_absolute_error: 9722.2950
# Epoch 48/200
#  - 1s - loss: 2939078675.8747 - mean_squared_error: 2939078675.8747 - mean_absolute_error: 9486.7420
# Epoch 49/200
#  - 1s - loss: 2367810797.4154 - mean_squared_error: 2367810797.4154 - mean_absolute_error: 9124.1267
# Epoch 50/200
#  - 1s - loss: 2006642687.5816 - mean_squared_error: 2006642687.5816 - mean_absolute_error: 9013.3802
# Epoch 51/200
#  - 1s - loss: 2327767526.4767 - mean_squared_error: 2327767526.4767 - mean_absolute_error: 9008.3259
# Epoch 52/200
#  - 1s - loss: 1761960910.7317 - mean_squared_error: 1761960910.7317 - mean_absolute_error: 8845.8229
# Epoch 53/200
#  - 1s - loss: 1784422995.1076 - mean_squared_error: 1784422995.1076 - mean_absolute_error: 8759.6400
# Epoch 54/200
#  - 1s - loss: 6756032064.4707 - mean_squared_error: 6756032064.4707 - mean_absolute_error: 12222.4099
# Epoch 55/200
#  - 1s - loss: 8548497872.7192 - mean_squared_error: 8548497872.7192 - mean_absolute_error: 12625.8861
# Epoch 56/200
#  - 1s - loss: 3555703996.8445 - mean_squared_error: 3555703996.8445 - mean_absolute_error: 9690.5006
# Epoch 57/200
#  - 1s - loss: 2578140224.6102 - mean_squared_error: 2578140224.6102 - mean_absolute_error: 8947.8570
# Epoch 58/200
#  - 1s - loss: 2320514174.3786 - mean_squared_error: 2320514174.3786 - mean_absolute_error: 9038.2258
# Epoch 59/200
#  - 1s - loss: 3435752404.2408 - mean_squared_error: 3435752404.2408 - mean_absolute_error: 9692.3188
# Epoch 60/200
#  - 1s - loss: 2038644457.8589 - mean_squared_error: 2038644457.8589 - mean_absolute_error: 8944.1723
# Epoch 61/200
#  - 1s - loss: 2111764076.8227 - mean_squared_error: 2111764076.8227 - mean_absolute_error: 8824.9583
# Epoch 62/200
#  - 1s - loss: 2179568935.6797 - mean_squared_error: 2179568935.6797 - mean_absolute_error: 9256.0779
# Epoch 63/200
#  - 1s - loss: 2150579267.6786 - mean_squared_error: 2150579267.6786 - mean_absolute_error: 9162.1626
# Epoch 64/200
#  - 1s - loss: 1874447850.8003 - mean_squared_error: 1874447850.8003 - mean_absolute_error: 8771.6225
# Epoch 65/200
#  - 1s - loss: 1769053732.2277 - mean_squared_error: 1769053732.2277 - mean_absolute_error: 8414.1689
# Epoch 66/200
#  - 1s - loss: 1898426786.3449 - mean_squared_error: 1898426786.3449 - mean_absolute_error: 8471.7557
# Epoch 67/200
#  - 1s - loss: 1451782698.6086 - mean_squared_error: 1451782698.6086 - mean_absolute_error: 8246.8483
# Epoch 68/200
#  - 1s - loss: 2019556141.1539 - mean_squared_error: 2019556141.1539 - mean_absolute_error: 8540.2048
# Epoch 69/200
#  - 1s - loss: 1532784279.8496 - mean_squared_error: 1532784279.8496 - mean_absolute_error: 8245.4679
# Epoch 70/200
#  - 1s - loss: 2175032814.1476 - mean_squared_error: 2175032814.1476 - mean_absolute_error: 8877.1540
# Epoch 71/200
#  - 1s - loss: 3239190239.5206 - mean_squared_error: 3239190239.5206 - mean_absolute_error: 9177.4176
# Epoch 72/200
#  - 1s - loss: 2469710370.9725 - mean_squared_error: 2469710370.9725 - mean_absolute_error: 9419.6411
# Epoch 73/200
#  - 1s - loss: 2364991013.3784 - mean_squared_error: 2364991013.3784 - mean_absolute_error: 9645.8052
# Epoch 74/200
#  - 1s - loss: 1949742884.1580 - mean_squared_error: 1949742884.1580 - mean_absolute_error: 8779.3900
# Epoch 75/200
#  - 1s - loss: 1522992358.7295 - mean_squared_error: 1522992358.7295 - mean_absolute_error: 8086.5563
# Epoch 76/200
#  - 1s - loss: 1921593376.7235 - mean_squared_error: 1921593376.7235 - mean_absolute_error: 8247.2358
# Epoch 77/200
#  - 1s - loss: 2570822418.4277 - mean_squared_error: 2570822418.4277 - mean_absolute_error: 9172.2171
# Epoch 78/200
#  - 1s - loss: 1503890221.5723 - mean_squared_error: 1503890221.5723 - mean_absolute_error: 8205.5560
# Epoch 79/200
#  - 1s - loss: 1881151917.5026 - mean_squared_error: 1881151917.5026 - mean_absolute_error: 8807.4851
# Epoch 80/200
#  - 1s - loss: 1413656748.8401 - mean_squared_error: 1413656748.8401 - mean_absolute_error: 7944.9337
# Epoch 81/200
#  - 1s - loss: 1188662347.5936 - mean_squared_error: 1188662347.5936 - mean_absolute_error: 7814.6272
# Epoch 82/200
#  - 1s - loss: 1452809918.4832 - mean_squared_error: 1452809918.4832 - mean_absolute_error: 7850.2792
# Epoch 83/200
#  - 1s - loss: 2988545214.1520 - mean_squared_error: 2988545214.1520 - mean_absolute_error: 8938.1378
# Epoch 84/200
#  - 1s - loss: 2595865182.8058 - mean_squared_error: 2595865182.8058 - mean_absolute_error: 9407.0830
# Epoch 85/200
#  - 1s - loss: 2542056296.2463 - mean_squared_error: 2542056296.2463 - mean_absolute_error: 9304.9870
# Epoch 86/200
#  - 1s - loss: 1371343375.8998 - mean_squared_error: 1371343375.8998 - mean_absolute_error: 7901.0526
# Epoch 87/200
#  - 1s - loss: 1367498253.5636 - mean_squared_error: 1367498253.5636 - mean_absolute_error: 7900.3696
# Epoch 88/200
#  - 1s - loss: 1521874801.5996 - mean_squared_error: 1521874801.5996 - mean_absolute_error: 7910.0922
# Epoch 89/200
#  - 1s - loss: 1864641218.1095 - mean_squared_error: 1864641218.1095 - mean_absolute_error: 8816.0603
# Epoch 90/200
#  - 1s - loss: 1718797556.4587 - mean_squared_error: 1718797556.4587 - mean_absolute_error: 8325.0693
# Epoch 91/200
#  - 1s - loss: 1425264499.7265 - mean_squared_error: 1425264499.7265 - mean_absolute_error: 8134.5817
# Epoch 92/200
#  - 1s - loss: 1167527587.2863 - mean_squared_error: 1167527587.2863 - mean_absolute_error: 7822.7563
# Epoch 93/200
#  - 1s - loss: 1300253482.3645 - mean_squared_error: 1300253482.3645 - mean_absolute_error: 7739.0064
# Epoch 94/200
#  - 1s - loss: 1078557659.0052 - mean_squared_error: 1078557659.0052 - mean_absolute_error: 7655.4950
# Epoch 95/200
#  - 1s - loss: 1017953239.7799 - mean_squared_error: 1017953239.7799 - mean_absolute_error: 7470.5995
# Epoch 96/200
#  - 1s - loss: 1220373493.1561 - mean_squared_error: 1220373493.1561 - mean_absolute_error: 7576.2500
# Epoch 97/200
#  - 1s - loss: 1199153112.6342 - mean_squared_error: 1199153112.6342 - mean_absolute_error: 7763.4286
# Epoch 98/200
#  - 1s - loss: 1021396375.3266 - mean_squared_error: 1021396375.3266 - mean_absolute_error: 7449.7052
# Epoch 99/200
#  - 1s - loss: 1332118124.6309 - mean_squared_error: 1332118124.6309 - mean_absolute_error: 7800.0012
# Epoch 100/200
#  - 1s - loss: 1142404121.4710 - mean_squared_error: 1142404121.4710 - mean_absolute_error: 7630.4641
# Epoch 101/200
#  - 1s - loss: 1393987589.6660 - mean_squared_error: 1393987589.6660 - mean_absolute_error: 7358.4570
# Epoch 102/200
#  - 1s - loss: 1152444635.3016 - mean_squared_error: 1152444635.3016 - mean_absolute_error: 7496.5054
# Epoch 103/200
#  - 1s - loss: 1417009658.2119 - mean_squared_error: 1417009658.2119 - mean_absolute_error: 7881.0934
# Epoch 104/200
#  - 1s - loss: 1099886890.5911 - mean_squared_error: 1099886890.5911 - mean_absolute_error: 7653.9460
# Epoch 105/200
#  - 1s - loss: 2928849629.9689 - mean_squared_error: 2928849629.9689 - mean_absolute_error: 8650.6927
# Epoch 106/200
#  - 1s - loss: 3064044877.2672 - mean_squared_error: 3064044877.2672 - mean_absolute_error: 9452.8109
# Epoch 107/200
#  - 1s - loss: 2259467207.8976 - mean_squared_error: 2259467207.8976 - mean_absolute_error: 8357.9444
# Epoch 108/200
#  - 1s - loss: 1499081162.2337 - mean_squared_error: 1499081162.2337 - mean_absolute_error: 8143.1248
# Epoch 109/200
#  - 1s - loss: 1680990158.7491 - mean_squared_error: 1680990158.7491 - mean_absolute_error: 8279.5369
# Epoch 110/200
#  - 1s - loss: 2931156033.6911 - mean_squared_error: 2931156033.6911 - mean_absolute_error: 8897.7258
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 0.009999999776482582.
# Epoch 111/200
#  - 1s - loss: 1784499141.9798 - mean_squared_error: 1784499141.9798 - mean_absolute_error: 8089.1533
# Epoch 112/200
#  - 1s - loss: 1539163952.7279 - mean_squared_error: 1539163952.7279 - mean_absolute_error: 8187.2027
# Epoch 113/200
#  - 1s - loss: 986322569.8153 - mean_squared_error: 986322569.8153 - mean_absolute_error: 7353.5559
# Epoch 114/200
#  - 1s - loss: 988023652.4108 - mean_squared_error: 988023652.4108 - mean_absolute_error: 7462.3757
# Epoch 115/200
#  - 1s - loss: 861630985.0395 - mean_squared_error: 861630985.0395 - mean_absolute_error: 7221.6044
# Epoch 116/200
#  - 1s - loss: 861218260.8859 - mean_squared_error: 861218260.8859 - mean_absolute_error: 7239.9953
# Epoch 117/200
#  - 1s - loss: 809962225.2335 - mean_squared_error: 809962225.2335 - mean_absolute_error: 7250.9322
# Epoch 118/200
#  - 1s - loss: 951503423.7385 - mean_squared_error: 951503423.7385 - mean_absolute_error: 7209.7035
# Epoch 119/200
#  - 1s - loss: 988300805.7358 - mean_squared_error: 988300805.7358 - mean_absolute_error: 7469.2388
# Epoch 120/200
#  - 1s - loss: 957491616.3225 - mean_squared_error: 957491616.3225 - mean_absolute_error: 7230.4223
# Epoch 121/200
#  - 1s - loss: 1060940796.8968 - mean_squared_error: 1060940796.8968 - mean_absolute_error: 7275.9602
# Epoch 122/200
#  - 1s - loss: 987618061.1452 - mean_squared_error: 987618061.1452 - mean_absolute_error: 7224.2956
# Epoch 123/200
#  - 1s - loss: 841326843.4236 - mean_squared_error: 841326843.4236 - mean_absolute_error: 7071.4258
# Epoch 124/200
#  - 1s - loss: 1162801811.6306 - mean_squared_error: 1162801811.6306 - mean_absolute_error: 7662.8703
# Epoch 125/200
#  - 1s - loss: 893576366.3917 - mean_squared_error: 893576366.3917 - mean_absolute_error: 7222.7434
# Epoch 126/200
#  - 1s - loss: 1165978502.5552 - mean_squared_error: 1165978502.5552 - mean_absolute_error: 7693.2282
# Epoch 127/200
#  - 1s - loss: 996482869.0341 - mean_squared_error: 996482869.0341 - mean_absolute_error: 7208.7856
# Epoch 128/200
#  - 1s - loss: 921932576.8630 - mean_squared_error: 921932576.8630 - mean_absolute_error: 7191.2035
# Epoch 129/200
#  - 1s - loss: 702858991.2983 - mean_squared_error: 702858991.2983 - mean_absolute_error: 6839.5028
# Epoch 130/200
#  - 1s - loss: 844564631.7625 - mean_squared_error: 844564631.7625 - mean_absolute_error: 7016.2806
# Epoch 131/200
#  - 1s - loss: 676928206.7142 - mean_squared_error: 676928206.7142 - mean_absolute_error: 6827.1797
# Epoch 132/200
#  - 1s - loss: 653978188.7791 - mean_squared_error: 653978188.7791 - mean_absolute_error: 6725.6305
# Epoch 133/200
#  - 1s - loss: 696689993.7630 - mean_squared_error: 696689993.7630 - mean_absolute_error: 6765.5115
# Epoch 134/200
#  - 1s - loss: 718618529.4296 - mean_squared_error: 718618529.4296 - mean_absolute_error: 6931.3034
# Epoch 135/200
#  - 1s - loss: 733762043.7461 - mean_squared_error: 733762043.7461 - mean_absolute_error: 6954.1398
# Epoch 136/200
#  - 1s - loss: 824494248.9000 - mean_squared_error: 824494248.9000 - mean_absolute_error: 6966.3232
# Epoch 137/200
#  - 1s - loss: 680852909.0232 - mean_squared_error: 680852909.0232 - mean_absolute_error: 6822.4240
# Epoch 138/200
#  - 1s - loss: 816814664.1068 - mean_squared_error: 816814664.1068 - mean_absolute_error: 6814.7492
# Epoch 139/200
#  - 1s - loss: 752973090.5541 - mean_squared_error: 752973090.5541 - mean_absolute_error: 6711.7646
# Epoch 140/200
#  - 1s - loss: 755816865.3163 - mean_squared_error: 755816865.3163 - mean_absolute_error: 6832.1775
# Epoch 141/200
#  - 1s - loss: 1083492643.1817 - mean_squared_error: 1083492643.1817 - mean_absolute_error: 7044.5565
# Epoch 142/200
#  - 1s - loss: 894699013.5789 - mean_squared_error: 894699013.5789 - mean_absolute_error: 6925.6548
# Epoch 143/200
#  - 1s - loss: 914741399.5445 - mean_squared_error: 914741399.5445 - mean_absolute_error: 7121.4103
# Epoch 144/200
#  - 1s - loss: 775645149.0885 - mean_squared_error: 775645149.0885 - mean_absolute_error: 6833.6223
# Epoch 145/200
#  - 1s - loss: 773054608.8586 - mean_squared_error: 773054608.8586 - mean_absolute_error: 6774.2503
# Epoch 146/200
#  - 1s - loss: 744205014.7862 - mean_squared_error: 744205014.7862 - mean_absolute_error: 6697.7907
# Epoch 147/200
#  - 1s - loss: 857572007.1915 - mean_squared_error: 857572007.1915 - mean_absolute_error: 6894.6704
#
# Epoch 00147: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 148/200
#  - 1s - loss: 760021351.9717 - mean_squared_error: 760021351.9717 - mean_absolute_error: 6831.4334
# Epoch 149/200
#  - 1s - loss: 774766839.3702 - mean_squared_error: 774766839.3702 - mean_absolute_error: 6576.0711
# Epoch 150/200
#  - 1s - loss: 740482724.4544 - mean_squared_error: 740482724.4544 - mean_absolute_error: 6722.9264
# Epoch 151/200
#  - 1s - loss: 756256593.8088 - mean_squared_error: 756256593.8088 - mean_absolute_error: 6650.6030
# Epoch 152/200
#  - 1s - loss: 600211729.3816 - mean_squared_error: 600211729.3816 - mean_absolute_error: 6622.4269
# Epoch 153/200
#  - 1s - loss: 635995795.8921 - mean_squared_error: 635995795.8921 - mean_absolute_error: 6589.4224
# Epoch 154/200
#  - 1s - loss: 616449459.0117 - mean_squared_error: 616449459.0117 - mean_absolute_error: 6547.5185
# Epoch 155/200
#  - 1s - loss: 620026171.6938 - mean_squared_error: 620026171.6938 - mean_absolute_error: 6561.3533
# Epoch 156/200
#  - 1s - loss: 831130807.4487 - mean_squared_error: 831130807.4487 - mean_absolute_error: 6762.9794
# Epoch 157/200
#  - 1s - loss: 563426982.3460 - mean_squared_error: 563426982.3460 - mean_absolute_error: 6504.3503
# Epoch 158/200
#  - 1s - loss: 567234632.3509 - mean_squared_error: 567234632.3509 - mean_absolute_error: 6371.8267
# Epoch 159/200
#  - 1s - loss: 662954045.9297 - mean_squared_error: 662954045.9297 - mean_absolute_error: 6447.1001
# Epoch 160/200
#  - 1s - loss: 676490700.0992 - mean_squared_error: 676490700.0992 - mean_absolute_error: 6671.5034
# Epoch 161/200
#  - 1s - loss: 657825832.7693 - mean_squared_error: 657825832.7693 - mean_absolute_error: 6507.2965
# Epoch 162/200
#  - 1s - loss: 671593830.7208 - mean_squared_error: 671593830.7208 - mean_absolute_error: 6529.6428
# Epoch 163/200
#  - 1s - loss: 685876880.3835 - mean_squared_error: 685876880.3835 - mean_absolute_error: 6573.8189
# Epoch 164/200
#  - 1s - loss: 618832861.5287 - mean_squared_error: 618832861.5287 - mean_absolute_error: 6510.4346
# Epoch 165/200
#  - 1s - loss: 750508820.2495 - mean_squared_error: 750508820.2495 - mean_absolute_error: 6646.2350
# Epoch 166/200
#  - 1s - loss: 597014388.9643 - mean_squared_error: 597014388.9643 - mean_absolute_error: 6418.2457
# Epoch 167/200
#  - 1s - loss: 626458054.8167 - mean_squared_error: 626458054.8167 - mean_absolute_error: 6431.5575
# Epoch 168/200
#  - 1s - loss: 597936751.1196 - mean_squared_error: 597936751.1196 - mean_absolute_error: 6492.0167
# Epoch 169/200
#  - 1s - loss: 550027534.4179 - mean_squared_error: 550027534.4179 - mean_absolute_error: 6391.5695
# Epoch 170/200
#  - 1s - loss: 601593483.8551 - mean_squared_error: 601593483.8551 - mean_absolute_error: 6367.4713
# Epoch 171/200
#  - 1s - loss: 659719330.9376 - mean_squared_error: 659719330.9376 - mean_absolute_error: 6455.0842
# Epoch 172/200
#  - 1s - loss: 522137762.8766 - mean_squared_error: 522137762.8766 - mean_absolute_error: 6251.0211
# Epoch 173/200
#  - 1s - loss: 704457012.5110 - mean_squared_error: 704457012.5110 - mean_absolute_error: 6533.4326
# Epoch 174/200
#  - 1s - loss: 602328432.1264 - mean_squared_error: 602328432.1264 - mean_absolute_error: 6508.3844
# Epoch 175/200
#  - 1s - loss: 614877042.5584 - mean_squared_error: 614877042.5584 - mean_absolute_error: 6323.2315
# Epoch 176/200
#  - 1s - loss: 683734992.1613 - mean_squared_error: 683734992.1613 - mean_absolute_error: 6328.3377
# Epoch 177/200
#  - 1s - loss: 752552763.6241 - mean_squared_error: 752552763.6241 - mean_absolute_error: 6551.3304
# Epoch 178/200
#  - 1s - loss: 774677248.3748 - mean_squared_error: 774677248.3748 - mean_absolute_error: 6469.6190
# Epoch 179/200
#  - 1s - loss: 528159264.1308 - mean_squared_error: 528159264.1308 - mean_absolute_error: 6285.6350
# Epoch 180/200
#  - 1s - loss: 684611593.1005 - mean_squared_error: 684611593.1005 - mean_absolute_error: 6610.0592
# Epoch 181/200
#  - 1s - loss: 623840435.5958 - mean_squared_error: 623840435.5958 - mean_absolute_error: 6337.4010
# Epoch 182/200
#  - 1s - loss: 664616430.4615 - mean_squared_error: 664616430.4615 - mean_absolute_error: 6473.2262
# Epoch 183/200
#  - 1s - loss: 569735455.5554 - mean_squared_error: 569735455.5554 - mean_absolute_error: 6286.5596
# Epoch 184/200
#  - 1s - loss: 606767516.0338 - mean_squared_error: 606767516.0338 - mean_absolute_error: 6381.1104
# Epoch 185/200
#  - 1s - loss: 564390449.8262 - mean_squared_error: 564390449.8262 - mean_absolute_error: 6241.0881
# Epoch 186/200
#  - 1s - loss: 514713106.2010 - mean_squared_error: 514713106.2010 - mean_absolute_error: 6197.3122
# Epoch 187/200
# ...
# Epoch 65/200
#  - 1s - loss: 2283985380.7333 - mean_squared_error: 2283985380.7333 - mean_absolute_error: 9230.2385
# Epoch 66/200
#  - 1s - loss: 1606280443.9205 - mean_squared_error: 1606280443.9205 - mean_absolute_error: 8456.1982
# Epoch 67/200
#  - 1s - loss: 1544625893.5178 - mean_squared_error: 1544625893.5178 - mean_absolute_error: 8566.8157
# Epoch 68/200
#  - 1s - loss: 2132819749.0646 - mean_squared_error: 2132819749.0646 - mean_absolute_error: 9443.4147
# Epoch 69/200
#  - 1s - loss: 2027601709.3282 - mean_squared_error: 2027601709.3282 - mean_absolute_error: 8926.7551
# Epoch 70/200
#  - 1s - loss: 1606661980.9403 - mean_squared_error: 1606661980.9403 - mean_absolute_error: 8668.2553
# Epoch 71/200
#  - 1s - loss: 1349029903.1152 - mean_squared_error: 1349029903.1152 - mean_absolute_error: 8456.1224
# Epoch 72/200
#  - 1s - loss: 1411656345.0700 - mean_squared_error: 1411656345.0700 - mean_absolute_error: 8189.5367
# Epoch 73/200
#  - 1s - loss: 1531132558.4702 - mean_squared_error: 1531132558.4702 - mean_absolute_error: 8190.3633
# Epoch 74/200
#  - 1s - loss: 1397615948.6396 - mean_squared_error: 1397615948.6396 - mean_absolute_error: 8182.8534
# Epoch 75/200
#  - 1s - loss: 1552247827.1773 - mean_squared_error: 1552247827.1773 - mean_absolute_error: 8204.0626
# Epoch 76/200
#  - 1s - loss: 1508659455.2852 - mean_squared_error: 1508659455.2852 - mean_absolute_error: 7952.0005
# Epoch 77/200
#  - 1s - loss: 1607585809.9221 - mean_squared_error: 1607585809.9221 - mean_absolute_error: 8363.4955
# Epoch 78/200
#  - 1s - loss: 1323231968.8717 - mean_squared_error: 1323231968.8717 - mean_absolute_error: 8267.5794
# Epoch 79/200
#  - 1s - loss: 1440503977.2487 - mean_squared_error: 1440503977.2487 - mean_absolute_error: 8051.5785
# Epoch 80/200
#  - 1s - loss: 1781082741.9580 - mean_squared_error: 1781082741.9580 - mean_absolute_error: 8357.2920
# Epoch 81/200
#  - 1s - loss: 1661404856.1634 - mean_squared_error: 1661404856.1634 - mean_absolute_error: 8121.6428
# Epoch 82/200
#  - 1s - loss: 1263721178.2032 - mean_squared_error: 1263721178.2032 - mean_absolute_error: 7613.6027
# Epoch 83/200
#  - 1s - loss: 966829026.1880 - mean_squared_error: 966829026.1880 - mean_absolute_error: 7288.9614
# Epoch 84/200
#  - 1s - loss: 1110054593.7260 - mean_squared_error: 1110054593.7260 - mean_absolute_error: 7524.8751
# Epoch 85/200
#  - 1s - loss: 1644984770.7023 - mean_squared_error: 1644984770.7023 - mean_absolute_error: 8085.5433
# Epoch 86/200
#  - 1s - loss: 1512933395.2296 - mean_squared_error: 1512933395.2296 - mean_absolute_error: 8178.8002
# Epoch 87/200
#  - 1s - loss: 1654257227.1752 - mean_squared_error: 1654257227.1752 - mean_absolute_error: 8012.1129
# Epoch 88/200
#  - 1s - loss: 1797586607.9695 - mean_squared_error: 1797586607.9695 - mean_absolute_error: 8267.8092
# Epoch 89/200
#  - 1s - loss: 1348615951.6905 - mean_squared_error: 1348615951.6905 - mean_absolute_error: 8262.8647
# Epoch 90/200
#  - 1s - loss: 1172807765.1648 - mean_squared_error: 1172807765.1648 - mean_absolute_error: 7639.3694
# Epoch 91/200
#  - 1s - loss: 1243895463.0520 - mean_squared_error: 1243895463.0520 - mean_absolute_error: 7681.1206
# Epoch 92/200
#  - 1s - loss: 1380011206.4767 - mean_squared_error: 1380011206.4767 - mean_absolute_error: 7884.2364
# Epoch 93/200
#  - 1s - loss: 1144854463.1632 - mean_squared_error: 1144854463.1632 - mean_absolute_error: 7567.2021
# Epoch 94/200
#  - 1s - loss: 1067652485.5440 - mean_squared_error: 1067652485.5440 - mean_absolute_error: 7347.2319
# Epoch 95/200
#  - 1s - loss: 906979331.6960 - mean_squared_error: 906979331.6960 - mean_absolute_error: 7528.1042
# Epoch 96/200
#  - 1s - loss: 992272125.4198 - mean_squared_error: 992272125.4198 - mean_absolute_error: 7177.9230
# Epoch 97/200
#  - 1s - loss: 1043287417.5843 - mean_squared_error: 1043287417.5843 - mean_absolute_error: 7702.9189
# Epoch 98/200
#  - 1s - loss: 989133055.0063 - mean_squared_error: 989133055.0063 - mean_absolute_error: 7357.1769
# Epoch 99/200
#  - 1s - loss: 2042567381.9145 - mean_squared_error: 2042567381.9145 - mean_absolute_error: 8329.3630
# Epoch 100/200
#  - 1s - loss: 1004088147.3865 - mean_squared_error: 1004088147.3865 - mean_absolute_error: 7938.1535
# Epoch 101/200
#  - 1s - loss: 1365517334.4026 - mean_squared_error: 1365517334.4026 - mean_absolute_error: 7482.2053
# Epoch 102/200
#  - 1s - loss: 1247063334.0757 - mean_squared_error: 1247063334.0757 - mean_absolute_error: 7355.8738
# Epoch 103/200
#  - 1s - loss: 1258339133.8382 - mean_squared_error: 1258339133.8382 - mean_absolute_error: 7490.6841
# Epoch 104/200
#  - 1s - loss: 1134721370.7088 - mean_squared_error: 1134721370.7088 - mean_absolute_error: 7278.0328
# Epoch 105/200
#  - 1s - loss: 1411210766.8712 - mean_squared_error: 1411210766.8712 - mean_absolute_error: 7463.6339
# Epoch 106/200
#  - 1s - loss: 903488702.8319 - mean_squared_error: 903488702.8319 - mean_absolute_error: 7496.7539
# Epoch 107/200
#  - 1s - loss: 1081519538.4015 - mean_squared_error: 1081519538.4015 - mean_absolute_error: 7329.3889
# Epoch 108/200
#  - 1s - loss: 1078090853.9537 - mean_squared_error: 1078090853.9537 - mean_absolute_error: 7230.3606
# Epoch 109/200
#  - 1s - loss: 1224320924.7137 - mean_squared_error: 1224320924.7137 - mean_absolute_error: 7610.3034
# Epoch 110/200
#  - 1s - loss: 1048620474.2119 - mean_squared_error: 1048620474.2119 - mean_absolute_error: 7167.7288
# Epoch 111/200
#  - 1s - loss: 1044587204.4457 - mean_squared_error: 1044587204.4457 - mean_absolute_error: 7457.7943
# Epoch 112/200
#  - 1s - loss: 882135682.4756 - mean_squared_error: 882135682.4756 - mean_absolute_error: 7407.4184
# Epoch 113/200
#  - 1s - loss: 979543512.6167 - mean_squared_error: 979543512.6167 - mean_absolute_error: 7072.6260
# Epoch 114/200
#  - 1s - loss: 706949343.3724 - mean_squared_error: 706949343.3724 - mean_absolute_error: 6756.0930
# Epoch 115/200
#  - 1s - loss: 850929703.3310 - mean_squared_error: 850929703.3310 - mean_absolute_error: 6737.9718
# Epoch 116/200
#  - 1s - loss: 1009058297.7586 - mean_squared_error: 1009058297.7586 - mean_absolute_error: 7100.3402
# Epoch 117/200
#  - 1s - loss: 1307069356.4130 - mean_squared_error: 1307069356.4130 - mean_absolute_error: 7196.2322
# Epoch 118/200
#  - 1s - loss: 1768404202.8178 - mean_squared_error: 1768404202.8178 - mean_absolute_error: 8291.0571
# Epoch 119/200
#  - 1s - loss: 1240015000.9218 - mean_squared_error: 1240015000.9218 - mean_absolute_error: 7569.0323
# Epoch 120/200
#  - 1s - loss: 1045591186.8810 - mean_squared_error: 1045591186.8810 - mean_absolute_error: 7399.3120
# Epoch 121/200
#  - 1s - loss: 1409454303.5729 - mean_squared_error: 1409454303.5729 - mean_absolute_error: 7311.3374
# Epoch 122/200
#  - 1s - loss: 814872496.3356 - mean_squared_error: 814872496.3356 - mean_absolute_error: 7143.2727
# Epoch 123/200
#  - 1s - loss: 762851483.5282 - mean_squared_error: 762851483.5282 - mean_absolute_error: 6761.5919
# Epoch 124/200
#  - 1s - loss: 1551587321.4448 - mean_squared_error: 1551587321.4448 - mean_absolute_error: 7351.7410
# Epoch 125/200
#  - 1s - loss: 713455914.5039 - mean_squared_error: 713455914.5039 - mean_absolute_error: 6917.5463
# Epoch 126/200
#  - 1s - loss: 744456077.2454 - mean_squared_error: 744456077.2454 - mean_absolute_error: 6730.6128
# Epoch 127/200
#  - 1s - loss: 772532755.2035 - mean_squared_error: 772532755.2035 - mean_absolute_error: 6628.0303
# Epoch 128/200
#  - 1s - loss: 935723422.0910 - mean_squared_error: 935723422.0910 - mean_absolute_error: 6994.0810
# Epoch 129/200
#  - 1s - loss: 1135017292.7093 - mean_squared_error: 1135017292.7093 - mean_absolute_error: 6892.5080
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 0.009999999776482582.
# Epoch 130/200
#  - 1s - loss: 859518167.6927 - mean_squared_error: 859518167.6927 - mean_absolute_error: 7059.4228
# Epoch 131/200
#  - 1s - loss: 699112501.1343 - mean_squared_error: 699112501.1343 - mean_absolute_error: 6407.7883
# Epoch 132/200
#  - 1s - loss: 937769706.2686 - mean_squared_error: 937769706.2686 - mean_absolute_error: 6601.3215
# Epoch 133/200
#  - 1s - loss: 653198378.7480 - mean_squared_error: 653198378.7480 - mean_absolute_error: 6250.3925
# Epoch 134/200
#  - 1s - loss: 693675582.2130 - mean_squared_error: 693675582.2130 - mean_absolute_error: 6311.3177
# Epoch 135/200
#  - 1s - loss: 556784993.8567 - mean_squared_error: 556784993.8567 - mean_absolute_error: 6193.0831
# Epoch 136/200
#  - 1s - loss: 779746712.6516 - mean_squared_error: 779746712.6516 - mean_absolute_error: 6400.4898
# Epoch 137/200
#  - 1s - loss: 745289771.8812 - mean_squared_error: 745289771.8812 - mean_absolute_error: 6604.1530
# Epoch 138/200
#  - 1s - loss: 787190899.3604 - mean_squared_error: 787190899.3604 - mean_absolute_error: 6261.8643
# Epoch 139/200
#  - 1s - loss: 647064815.9869 - mean_squared_error: 647064815.9869 - mean_absolute_error: 6406.7515
# Epoch 140/200
#  - 1s - loss: 547562628.8292 - mean_squared_error: 547562628.8292 - mean_absolute_error: 6187.9011
# Epoch 141/200
#  - 1s - loss: 463134046.4222 - mean_squared_error: 463134046.4222 - mean_absolute_error: 5978.8709
# Epoch 142/200
#  - 1s - loss: 679354266.3427 - mean_squared_error: 679354266.3427 - mean_absolute_error: 6305.1313
# Epoch 143/200
#  - 1s - loss: 650584554.6783 - mean_squared_error: 650584554.6783 - mean_absolute_error: 6143.2843
# Epoch 144/200
#  - 1s - loss: 846550117.0820 - mean_squared_error: 846550117.0820 - mean_absolute_error: 6514.8827
# Epoch 145/200
#  - 1s - loss: 994556893.1670 - mean_squared_error: 994556893.1670 - mean_absolute_error: 6791.3452
# Epoch 146/200
#  - 1s - loss: 1001318026.6957 - mean_squared_error: 1001318026.6957 - mean_absolute_error: 6531.1583
# Epoch 147/200
#  - 1s - loss: 701617023.1806 - mean_squared_error: 701617023.1806 - mean_absolute_error: 6565.6384
# Epoch 148/200
#  - 1s - loss: 619374769.8698 - mean_squared_error: 619374769.8698 - mean_absolute_error: 6091.0771
# Epoch 149/200
#  - 1s - loss: 539525789.7249 - mean_squared_error: 539525789.7249 - mean_absolute_error: 6068.8413
# Epoch 150/200
#  - 1s - loss: 717801395.8137 - mean_squared_error: 717801395.8137 - mean_absolute_error: 6304.7750
# Epoch 151/200
#  - 1s - loss: 642195806.3351 - mean_squared_error: 642195806.3351 - mean_absolute_error: 6163.1587
# Epoch 152/200
#  - 1s - loss: 626940118.1934 - mean_squared_error: 626940118.1934 - mean_absolute_error: 6122.9326
# Epoch 153/200
#  - 1s - loss: 695609728.9414 - mean_squared_error: 695609728.9414 - mean_absolute_error: 6193.6633
# Epoch 154/200
#  - 1s - loss: 796593435.3974 - mean_squared_error: 796593435.3974 - mean_absolute_error: 6272.4158
# Epoch 155/200
#  - 1s - loss: 708688608.9850 - mean_squared_error: 708688608.9850 - mean_absolute_error: 6390.7672
# Epoch 156/200
#  - 1s - loss: 733622835.6393 - mean_squared_error: 733622835.6393 - mean_absolute_error: 6459.8447
#
# Epoch 00156: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 157/200
#  - 1s - loss: 767881705.3795 - mean_squared_error: 767881705.3795 - mean_absolute_error: 6367.0912
# Epoch 158/200
#  - 1s - loss: 559595099.8071 - mean_squared_error: 559595099.8071 - mean_absolute_error: 5973.6552
# Epoch 159/200
#  - 1s - loss: 519463665.2247 - mean_squared_error: 519463665.2247 - mean_absolute_error: 5933.0293
# Epoch 160/200
#  - 1s - loss: 566820731.4149 - mean_squared_error: 566820731.4149 - mean_absolute_error: 5989.7553
# Epoch 161/200
#  - 1s - loss: 669611739.3887 - mean_squared_error: 669611739.3887 - mean_absolute_error: 6084.5279
# Epoch 162/200
#  - 1s - loss: 613755296.2223 - mean_squared_error: 613755296.2223 - mean_absolute_error: 6229.6447
# Epoch 163/200
#  - 1s - loss: 453458342.1716 - mean_squared_error: 453458342.1716 - mean_absolute_error: 5893.2820
# Epoch 164/200
#  - 1s - loss: 623242205.9777 - mean_squared_error: 623242205.9777 - mean_absolute_error: 5952.1538
# Epoch 165/200
#  - 1s - loss: 611969409.8654 - mean_squared_error: 611969409.8654 - mean_absolute_error: 6041.9049
# Epoch 166/200
#  - 1s - loss: 511562288.1700 - mean_squared_error: 511562288.1700 - mean_absolute_error: 5859.1992
# Epoch 167/200
#  - 1s - loss: 672635296.1220 - mean_squared_error: 672635296.1220 - mean_absolute_error: 6107.2598
# Epoch 168/200
#  - 1s - loss: 605143333.7619 - mean_squared_error: 605143333.7619 - mean_absolute_error: 6076.1878
# Epoch 169/200
#  - 1s - loss: 555243146.9398 - mean_squared_error: 555243146.9398 - mean_absolute_error: 5876.9729
# Epoch 170/200
#  - 1s - loss: 524793352.3160 - mean_squared_error: 524793352.3160 - mean_absolute_error: 5814.5183
# Epoch 171/200
#  - 1s - loss: 458485453.0057 - mean_squared_error: 458485453.0057 - mean_absolute_error: 6074.8404
# Epoch 172/200
#  - 1s - loss: 610866926.2261 - mean_squared_error: 610866926.2261 - mean_absolute_error: 5975.8464
# Epoch 173/200
#  - 1s - loss: 618264505.7761 - mean_squared_error: 618264505.7761 - mean_absolute_error: 5889.8226
# Epoch 174/200
#  - 1s - loss: 531718341.5309 - mean_squared_error: 531718341.5309 - mean_absolute_error: 5896.2334
# Epoch 175/200
#  - 1s - loss: 535782155.2536 - mean_squared_error: 535782155.2536 - mean_absolute_error: 5970.9331
# Epoch 176/200
#  - 1s - loss: 550672818.8374 - mean_squared_error: 550672818.8374 - mean_absolute_error: 5821.2637
# Epoch 177/200
#  - 1s - loss: 439813676.2212 - mean_squared_error: 439813676.2212 - mean_absolute_error: 5778.0865
# Epoch 178/200
#  - 1s - loss: 491064863.4334 - mean_squared_error: 491064863.4334 - mean_absolute_error: 5726.0187
# Epoch 179/200
#  - 1s - loss: 485781250.5802 - mean_squared_error: 485781250.5802 - mean_absolute_error: 5886.1613
# Epoch 180/200
#  - 1s - loss: 461076836.3149 - mean_squared_error: 461076836.3149 - mean_absolute_error: 5685.3977
# Epoch 181/200
#  - 1s - loss: 477051860.1362 - mean_squared_error: 477051860.1362 - mean_absolute_error: 5809.8538
# Epoch 182/200
#  - 1s - loss: 485840091.7025 - mean_squared_error: 485840091.7025 - mean_absolute_error: 5726.0868
# Epoch 183/200
#  - 1s - loss: 504306534.6336 - mean_squared_error: 504306534.6336 - mean_absolute_error: 5801.9575
# Epoch 184/200
#  - 1s - loss: 572332886.2370 - mean_squared_error: 572332886.2370 - mean_absolute_error: 5762.0045
# Epoch 185/200
#  - 1s - loss: 510753308.2779 - mean_squared_error: 510753308.2779 - mean_absolute_error: 5780.9019
# Epoch 186/200
#  - 1s - loss: 579848552.8129 - mean_squared_error: 579848552.8129 - mean_absolute_error: 5766.7115
# Epoch 187/200
#  - 1s - loss: 782591159.0041 - mean_squared_error: 782591159.0041 - mean_absolute_error: 6148.5543
# Epoch 188/200
#  - 1s - loss: 553676516.8554 - mean_squared_error: 553676516.8554 - mean_absolute_error: 5905.5916
# Epoch 189/200
#  - 1s - loss: 462537747.5434 - mean_squared_error: 462537747.5434 - mean_absolute_error: 5717.1650
# Epoch 190/200
#  - 1s - loss: 539468870.8515 - mean_squared_error: 539468870.8515 - mean_absolute_error: 5882.9824
# Epoch 191/200
#  - 1s - loss: 516046315.5936 - mean_squared_error: 516046315.5936 - mean_absolute_error: 5979.7471
# Epoch 192/200
#  - 1s - loss: 604336198.8864 - mean_squared_error: 604336198.8864 - mean_absolute_error: 5793.8053
#
# Epoch 00192: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 193/200
#  - 1s - loss: 581813281.0373 - mean_squared_error: 581813281.0373 - mean_absolute_error: 5710.5457
# Epoch 194/200
#  - 1s - loss: 448394374.6554 - mean_squared_error: 448394374.6554 - mean_absolute_error: 5720.2667
# Epoch 195/200
#  - 1s - loss: 523946039.2089 - mean_squared_error: 523946039.2089 - mean_absolute_error: 5820.8515
# Epoch 196/200
#  - 1s - loss: 574869655.7625 - mean_squared_error: 574869655.7625 - mean_absolute_error: 5689.4961
# Epoch 197/200
#  - 1s - loss: 466091235.3735 - mean_squared_error: 466091235.3735 - mean_absolute_error: 5631.2986
# Epoch 198/200
#  - 1s - loss: 451653198.5355 - mean_squared_error: 451653198.5355 - mean_absolute_error: 5780.6185
# Epoch 199/200
#  - 1s - loss: 402080869.4568 - mean_squared_error: 402080869.4568 - mean_absolute_error: 5605.4592
# Epoch 200/200
#  - 1s - loss: 457703971.1991 - mean_squared_error: 457703971.1991 - mean_absolute_error: 5593.8595
# model saved to models/2018-07-04_19-52-38.h5
# done !
# K-fold validation results :
# Mean squared error : 4106210154.16 (std 1124952244.62)
# Mean absolute error : 8493.65 (std 644.45)
# Sum of absolute errors : 83146756.99 (std 6312373.09)

# %% [markdown]
# # Prediction

# %%
prediction_dataset = '../../data/lightrasters_noaa/2012_south_america.tif'

print('loading model')

cnn = models.load_model("models/" + model_birthday + ".h5")

print('opening raster')

raster = rasterio.open(prediction_dataset)
band = raster.read(1)
profile = raster.profile
profile.update(count=1)
width, height = raster.width, raster.height

# preprocess
matrix_x = raster.read(1)
tiles_x = []
y = 0
while y + input_tile_size < matrix_x.shape[1]:
    x = 0
    while x + input_tile_size < matrix_x.shape[0]:
        tiles_x.append(matrix_x[x: x + input_tile_size, y: y + input_tile_size])
        x += input_tile_size
    y += input_tile_size
testX = np.array(tiles_x)

raster.close()
testX = np.expand_dims(testX, axis=3)

print('generating raster')

predicted_tiles = cnn.predict(testX, verbose=0)

tiles_x = []
predicted_raster = np.zeros(shape=(raster.height, raster.width))
y = 0
pred_index = 0
while y + input_tile_size < width:
    x = 0
    while x + input_tile_size < height:
        in_tile = band[x: x + input_tile_size, y: y + input_tile_size]
        if np.max(in_tile) <= 0:
            predicted_raster[x: x + input_tile_size, y: y + input_tile_size] = 0
        else:
            weights = in_tile / np.max(in_tile)  # normalize visible light between 0 and 1 to avoid overflows
            weights = np.exp(weights) - 1  # visible light is perceived logarithmically => counteract with exp
            weights = weights / np.sum(weights)  # the sum of all weights must be 1
            predicted_raster[x: x + input_tile_size, y: y + input_tile_size] = predicted_tiles[pred_index] * weights

        pred_index += 1
        x += input_tile_size
    y += input_tile_size

predicted_raster = np.array(predicted_raster)

with rasterio.open('predictions/' + model_birthday + '.tif', 'w', **profile) as dst:
    dst.write(predicted_raster.astype(rasterio.float32), 1)
print("prediction saved to predictions/" + model_birthday + '.tif')

print('prediction done !')
